# %%
import json
from urllib.request import urlopen
import requests
import pandas as pd
from datetime import datetime
import sqlalchemy
from shapely.geometry import Point
import xmltodict

# %%
postgres_engine = sqlalchemy.create_engine('postgresql://postgres:Admin1server1!@postgres-dev.cluster-c2k5rcppbf2p.us-east-1.rds.amazonaws.com:5432/dw', connect_args={'connect_timeout': 10}, echo=False)

# %%
# '''Constructors'''
# limit= 100
# offset= 0
# url = "http://ergast.com/api/f1/constructors?limit={}&offset={}".format(limit,offset)
# # url = "http://ergast.com/api/f1/seasons?limit={}&offset={}".format(limit,offset)

# payload = {}
# headers = {"Content-Type":"application/xml; charset=utf-8"}

# #http://dicomcloud.com/docs/dicomcloud/pagination/
# response = requests.get(url, headers=headers, data=payload)
 
# print(response.text)

# data_dict = xmltodict.parse(response.text)['MRData']['ConstructorTable']
# unnested_metric_data = pd.json_normalize(data_dict, record_path =['Constructor'])

# unnested_metric_data

# %%
#Results
limit= 100
offset= 0
url = "http://ergast.com/api/f1/current/last/results.json?limit={}&offset={}.json".format(limit,offset)

payload = {}
headers = {}

#http://dicomcloud.com/docs/dicomcloud/pagination/
# response = requests.request("GET", url, headers=headers, data=payload)
response = requests.get(url, headers=headers, data=payload)
 
races_str = response.json()['MRData']['RaceTable']['Races'][0]
races_str

races = pd.json_normalize(races_str, record_path =['Results'], 
                            meta= [
                                'season', 'round', 'raceName', ['Circuit', 'circuitId'], ['Circuit', 'circuitName'], 
                                ['Circuit','Location', 'lat'], ['Circuit', 'Location', 'long'], ['Circuit', 'Location', 'locality'], 
                                ['Circuit', 'Location', 'country'], 'date', 'time'
                                ]
                        )
races['_etl_loaded_at']= datetime.now().strftime("%d/%m/%Y %H:%M:%S")

races
# Out:
#    number position positionText points grid laps            status  \
# 0       1        1            1     26    1   52          Finished
# 1       4        2            2     18    2   52          Finished
# 2      44        3            3     15    7   52          Finished
# 3      81        4            4     12    3   52          Finished
# 4      63        5            5     10    6   52          Finished
# 5      11        6            6      8   15   52          Finished
# 6      14        7            7      6    9   52          Finished
# 7      23        8            8      4    8   52          Finished
# 8      16        9            9      2    4   52          Finished
# 9      55       10           10      1    5   52          Finished
# 10      2       11           11      0   14   52          Finished
# 11     77       12           12      0   20   52          Finished
# 12     27       13           13      0   11   52          Finished
# ...

# %%
years= [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023]

# %%
# '''Race Results for all years (2013 - 2023)'''
# limit= 100
# offset= 0
# payload = {}
# headers = {}
# years= [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023]
# # yr_round= 2
# races= pd.DataFrame(columns=['number', 'position', 'positionText', 'points', 'grid', 'laps',
#        'status', 'Driver.driverId', 'Driver.permanentNumber', 'Driver.code',
#        'Driver.url', 'Driver.givenName', 'Driver.familyName',
#        'Driver.dateOfBirth', 'Driver.nationality', 'Constructor.constructorId',
#        'Constructor.url', 'Constructor.name', 'Constructor.nationality',
#        'Time.millis', 'Time.time', 'FastestLap.rank', 'FastestLap.lap',
#        'FastestLap.Time.time', 'FastestLap.AverageSpeed.units',
#        'FastestLap.AverageSpeed.speed', 'season', 'round', 'raceName',
#        'Circuit.circuitId', 'date', 'time'])
# for year in years:
#     print(year)
#     for yr_round in range(1,25):
#         try:
#             print (yr_round)
#             url = "http://ergast.com/api/f1/{year}/{yr_round}/results.json?limit={limit}&offset={offset}".format(year=year,yr_round=yr_round,limit= limit,offset= offset)
            
#             response = requests.request("GET", url, headers=headers, data=payload)
            
#             race_str = response.json()['MRData']['RaceTable']['Races'][0]

#             race = pd.json_normalize(race_str, record_path =['Results'], 
#                                     meta= [
#                                         'season', 'round', 'raceName', ['Circuit', 'circuitId'], 'date', 'time'
#                                         ]
#                                 )
#             races= pd.concat([races, race], ignore_index=True)
#         except IndexError:
#             print("There was no round {} in {} season".format(yr_round, year))
#             pass

# races['_etl_loaded_at']= datetime.now().strftime("%d/%m/%Y %H:%M:%S")
# races["datetime"] = races["date"] + ' ' +races["time"]
# races

# %%
'''Race Results for all years (2013 - 2023)'''
limit= 1000
offset= 0
payload = {}
headers = {}
years= [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023]
# yr_round= 2
races= pd.DataFrame(columns=['number', 'position', 'positionText', 'points', 'grid', 'laps',
       'status', 'Driver.driverId', 'Driver.permanentNumber', 'Driver.code',
       'Driver.url', 'Driver.givenName', 'Driver.familyName',
       'Driver.dateOfBirth', 'Driver.nationality', 'Constructor.constructorId',
       'Constructor.url', 'Constructor.name', 'Constructor.nationality',
       'Time.millis', 'Time.time', 'FastestLap.rank', 'FastestLap.lap',
       'FastestLap.Time.time', 'FastestLap.AverageSpeed.units',
       'FastestLap.AverageSpeed.speed', 'season', 'round', 'raceName',
       'Circuit.circuitId', 'date', 'time'])
for year in years:
    print(year)
    url = "http://ergast.com/api/f1/{year}/results.json?limit={limit}&offset={offset}".format(year=year,limit= limit,offset= offset)
    
    response = requests.request("GET", url, headers=headers, data=payload)
    
    race_str = response.json()['MRData']['RaceTable']['Races']

    race = pd.json_normalize(race_str, record_path =['Results'], 
                            meta= [
                                'season', 'round', 'raceName', ['Circuit', 'circuitId'], 'date', 'time'
                                ]
                        )
    races= pd.concat([races, race], ignore_index=True)

races['_etl_loaded_at']= datetime.now().strftime("%Y-%m-%d %H:%M:%S")
races["datetime_utc"] = races["date"] + ' ' +races["time"]
races
# Out:
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020
# 2021
# 2022
# 2023
#      number position positionText points grid laps            status  \
# 0         7        1            1     25    7   58          Finished
# 1         3        2            2     18    5   58          Finished
# 2         1        3            3     15    1   58          Finished
# 3         4        4            4     12    4   58          Finished
# 4        10        5            5     10    3   58          Finished
# ...     ...      ...          ...    ...  ...  ...               ...
# 4320     22       16           16      0   16   52          Finished
# 4321     21       17           17      0   18   52          Finished
# 4322     10       18           18      0   10   46  Collision damage
# 4323     20       19            R      0   19   31            Engine
# 4324     31       20            R      0   13    9          Oil leak
#
# ...

# %%
fact_races_result= races[['Driver.driverId','Constructor.constructorId', 'raceName', 'season', 'round', 'Circuit.circuitId', 'number', 'position', 'positionText', 'points', 'grid', 'laps',
       'status',  'Time.millis', 'Time.time', 'FastestLap.rank', 'FastestLap.lap',
       'FastestLap.AverageSpeed.speed', 'datetime_utc', '_etl_loaded_at']]

fact_races_result.rename(columns={'Driver.driverId': 'driverId', 'Constructor.constructorId': 'constructorId', 
                                  'Circuit.circuitId': 'circuitId', 'Time.millis': 'timeMillis', 'Time.time': 'timeTime',
                                  'FastestLap.rank': 'fastestLapRank', 'FastestLap.lap': 'FastestLap', 'FastestLap.AverageSpeed.speed': 'fastestLapAverageSpeed'}, inplace=True)


fact_races_result
# Out:
# /var/folders/04/hsnx648d651fvt6_6xtszk540000gn/T/ipykernel_3720/2054526911.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fact_races_result.rename(columns={'Driver.driverId': 'driverId', 'Constructor.constructorId': 'constructorId',
#              driverId constructorId               raceName season round  \
# 0           raikkonen      lotus_f1  Australian Grand Prix   2013     1
# 1              alonso       ferrari  Australian Grand Prix   2013     1
# 2              vettel      red_bull  Australian Grand Prix   2013     1
# 3               massa       ferrari  Australian Grand Prix   2013     1
# 4            hamilton      mercedes  Australian Grand Prix   2013     1
# ...               ...           ...                    ...    ...   ...
# ...

# %%
fact_races_result.columns
# Out:
# Index(['driverId', 'constructorId', 'raceName', 'season', 'round', 'circuitId',
#        'number', 'position', 'positionText', 'points', 'grid', 'laps',
#        'status', 'timeMillis', 'timeTime', 'fastestLapRank', 'FastestLap',
#        'fastestLapAverageSpeed', 'datetime_utc', '_etl_loaded_at'],
#       dtype='object')

# %%
# fact_races_result= fact_races_result.convert_dtypes()       #convert all columns to string, first

fact_races_result[['datetime_utc', '_etl_loaded_at']]= fact_races_result[['datetime_utc', '_etl_loaded_at']].apply(pd.to_datetime, format='%Y-%m-%d %H:%M:%S')

convert_dict = {'round': int,
                'points': float, 
                'laps': int, 
                'timeMillis': float, 
                'fastestLapAverageSpeed': float, 
                }
fact_races_result = fact_races_result.astype(convert_dict)

fact_races_result.dtypes
# Out:
# /var/folders/04/hsnx648d651fvt6_6xtszk540000gn/T/ipykernel_3720/1465304251.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fact_races_result[['datetime_utc', '_etl_loaded_at']]= fact_races_result[['datetime_utc', '_etl_loaded_at']].apply(pd.to_datetime, format='%Y-%m-%d %H:%M:%S')
# driverId                               object
# constructorId                          object
# raceName                               object
# season                                 object
# round                                   int64
# circuitId                              object
# number                                 object
# position                               object
# positionText                           object
# ...

# %%
fact_races_result.to_sql('raw_races_result', con= postgres_engine, schema='staging', if_exists='append', method='multi', chunksize= 500, index= False)
# Out:
# 4325

# %%
# fact_races_result.to_sql('raw_races_result', con= postgres_engine, schema='staging', if_exists='append', method='multi', chunksize= 500, index= False,
#                          dtype={'round': sqlalchemy.types.INTEGER(), 
#                                 'points': sqlalchemy.types.Float(precision=1, asdecimal=True), 
#                                 'laps': sqlalchemy.types.INTEGER(), 
#                                 'timeMillis': sqlalchemy.types.INTEGER(), 
#                                 'fastestLapAverageSpeed': sqlalchemy.types.Float(precision=3, asdecimal=True), 
#                                 'datetime':sqlalchemy.DateTime(), 
#                                 '_etl_loaded_at': sqlalchemy.DateTime()})
# Out:
# 4325

# %% [markdown]
# Constructors

# %%
'''Constructors: List of all Constructors'''
#Needs to be iterated over the total (total_constructors)
limit= 1500
offset= 0
url = "http://ergast.com/api/f1/constructors.json?limit={limit}&offset={offset}".format(limit=limit,offset=offset)

payload = {}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)
 
constructors_str, total_constructors = response.json()['MRData']['ConstructorTable'], response.json()['MRData']['total']

constructors = pd.json_normalize(constructors_str, record_path =['Constructors']
                                )

constructors['_etl_loaded_at']= datetime.now().strftime("%Y-%m-%d %H:%M:%S")
constructors
# Out:
#     constructorId                                                url  \
# 0           adams   http://en.wikipedia.org/wiki/Adams_(constructor)
# 1             afm  http://en.wikipedia.org/wiki/Alex_von_Falkenha...
# 2             ags  http://en.wikipedia.org/wiki/Automobiles_Gonfa...
# 3            alfa  http://en.wikipedia.org/wiki/Alfa_Romeo_in_For...
# 4      alphatauri   http://en.wikipedia.org/wiki/Scuderia_AlphaTauri
# ..            ...                                                ...
# 206        watson           http://en.wikipedia.org/wiki/A.J._Watson
# 207     wetteroth             http://en.wikipedia.org/wiki/Wetteroth
# 208      williams  http://en.wikipedia.org/wiki/Williams_Grand_Pr...
# 209          wolf    http://en.wikipedia.org/wiki/Walter_Wolf_Racing
# 210      zakspeed              http://en.wikipedia.org/wiki/Zakspeed
#
#            name nationality       _etl_loaded_at
# 0         Adams    American  2023-07-15 08:16:16
# ...

# %%
# constructors= constructors.convert_dtypes()       #convert all columns to string, first

constructors[['_etl_loaded_at']]= constructors[['_etl_loaded_at']].apply(pd.to_datetime, format='%Y-%m-%d %H:%M:%S')
constructors.dtypes
# Out:
# constructorId             object
# url                       object
# name                      object
# nationality               object
# _etl_loaded_at    datetime64[ns]
# dtype: object

# %%
constructors.to_sql('raw_constructors', con= postgres_engine, schema='staging', if_exists='append', method='multi', chunksize= 500, index= False,
                         )
# Out:
# 211

# %%
'''Schedule: List of all Schedules'''
limit= 1000
offset= 0

schedules= pd.DataFrame(columns=['season', 'round', 'url', 'raceName', 'date', 'time',
       'Circuit.circuitId', 'Circuit.url', 'Circuit.circuitName',
       'Circuit.Location.lat', 'Circuit.Location.long',
       'Circuit.Location.locality', 'Circuit.Location.country',
       'FirstPractice.date', 'FirstPractice.time', 'SecondPractice.date',
       'SecondPractice.time', 'ThirdPractice.date', 'ThirdPractice.time',
       'Qualifying.date', 'Qualifying.time', 'Sprint.date', 'Sprint.time']
       )

payload = {}
headers = {}

for year in years:
    url = "http://ergast.com/api/f1/{year}.json?limit={limit}&offset={offset}".format(year= year, limit= limit, offset= offset)
    
    response = requests.request("GET", url, headers=headers, data=payload)

    schedule_str = response.json()['MRData']['RaceTable']

    schedule = pd.json_normalize(schedule_str, record_path =['Races'])

    schedules= pd.concat([schedules, schedule], ignore_index=True)

schedules['_etl_loaded_at']= datetime.now().strftime("%Y-%m-%d %H:%M:%S")
schedules
# Out:
#     season round                                                url  \
# 0     2013     1  http://en.wikipedia.org/wiki/2013_Australian_G...
# 1     2013     2  http://en.wikipedia.org/wiki/2013_Malaysian_Gr...
# 2     2013     3  http://en.wikipedia.org/wiki/2013_Chinese_Gran...
# 3     2013     4  http://en.wikipedia.org/wiki/2013_Bahrain_Gran...
# 4     2013     5  http://en.wikipedia.org/wiki/2013_Spanish_Gran...
# ..     ...   ...                                                ...
# 218   2023    18  https://en.wikipedia.org/wiki/2023_United_Stat...
# 219   2023    19  https://en.wikipedia.org/wiki/2023_Mexico_City...
# 220   2023    20  https://en.wikipedia.org/wiki/2023_S%C3%A3o_Pa...
# 221   2023    21  https://en.wikipedia.org/wiki/2023_Las_Vegas_G...
# 222   2023    22  https://en.wikipedia.org/wiki/2023_Abu_Dhabi_G...
#
#                      raceName        date       time Circuit.circuitId  \
# 0       Australian Grand Prix  2013-03-17  06:00:00Z       albert_park
# ...

# %%
#Select the necessary columns
dim_schedules= schedules[['season', 'round', 'url', 'raceName', 'date', 'time',
       'Circuit.circuitId','FirstPractice.date', 'FirstPractice.time', 'SecondPractice.date',
       'SecondPractice.time', 'ThirdPractice.date', 'ThirdPractice.time',
       'Qualifying.date', 'Qualifying.time', 'Sprint.date', 'Sprint.time',
       '_etl_loaded_at']]

#Transform each date and time columns into single columns
dim_schedules["firstPracticeDatetime"] = dim_schedules["FirstPractice.date"] + ' ' + dim_schedules["FirstPractice.time"]
dim_schedules["secondPracticeDatetime"] = dim_schedules["SecondPractice.date"] + ' ' + dim_schedules["SecondPractice.time"]
dim_schedules["thirdtPracticeDatetime"] = dim_schedules["ThirdPractice.date"] + ' ' + dim_schedules["ThirdPractice.time"]
dim_schedules["qualifyingDatetime"] = dim_schedules["Qualifying.date"] + ' ' + dim_schedules["Qualifying.time"]
dim_schedules["sprintDatetime"] = dim_schedules["Sprint.date"] + ' ' + dim_schedules["Sprint.time"]
dim_schedules["datetime"] = dim_schedules["date"] + ' ' + dim_schedules["time"]

#ignore the solo date and times
dim_schedules= dim_schedules.loc[:, ~dim_schedules.columns.isin(['date', 'time', 'FirstPractice.date', 'FirstPractice.time', 'SecondPractice.date',
                                                  'SecondPractice.time', 'ThirdPractice.date', 'ThirdPractice.time','Qualifying.date', 
                                                  'Qualifying.time', 'Sprint.date', 'Sprint.time',])]

#rename column(s)
dim_schedules.rename(columns={'Circuit.circuitId': 'circuitId',
                            #   'FirstPractice.date': 'firstPracticeDate', 
                            #       'FirstPractice.time': 'firstPracticeTime', 'SecondPractice.date': 'secondPracticeDate', 
                            #       'SecondPractice.time': 'secondPracticeTime','ThirdPractice.date': 'thirdPracticeDate', 
                            #       'ThirdPractice.time': 'thirdPracticeTime','Qualifying.date': 'qualifyingDate', 'Qualifying.time': 'qualifyingTime',
                            #       'Sprint.date': 'sprintDate', 'Sprint.time': 'sprintTime'
                                  }, inplace=True)

#sort the columns
dim_schedules= dim_schedules[['datetime','season', 'round', 'url', 'raceName', 'circuitId','firstPracticeDatetime', 
                              'secondPracticeDatetime','thirdtPracticeDatetime', 'qualifyingDatetime', 'sprintDatetime', '_etl_loaded_at']]

dim_schedules
# Out:
# /var/folders/04/hsnx648d651fvt6_6xtszk540000gn/T/ipykernel_3720/1301045364.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dim_schedules["firstPracticeDatetime"] = dim_schedules["FirstPractice.date"] + ' ' + dim_schedules["FirstPractice.time"]
# /var/folders/04/hsnx648d651fvt6_6xtszk540000gn/T/ipykernel_3720/1301045364.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#update datatypes
# dim_schedules= dim_schedules.convert_dtypes()       #convert all columns to string, first

dim_schedules[['datetime','firstPracticeDatetime', 'secondPracticeDatetime',
               'thirdtPracticeDatetime', 'qualifyingDatetime', 
               'sprintDatetime', '_etl_loaded_at']]= dim_schedules[['datetime','firstPracticeDatetime', 'secondPracticeDatetime',
                                                                    'thirdtPracticeDatetime', 'qualifyingDatetime', 
                                                                    'sprintDatetime', '_etl_loaded_at']].apply(pd.to_datetime, format='%Y-%m-%d %H:%M:%S')

convert_dict = {'round': int
                }
dim_schedules = dim_schedules.astype(convert_dict)

dim_schedules.dtypes
# Out:
# datetime                  datetime64[ns, UTC]
# season                                 object
# round                                   int64
# url                                    object
# raceName                               object
# circuitId                              object
# firstPracticeDatetime     datetime64[ns, UTC]
# secondPracticeDatetime    datetime64[ns, UTC]
# thirdtPracticeDatetime    datetime64[ns, UTC]
# qualifyingDatetime        datetime64[ns, UTC]
# sprintDatetime            datetime64[ns, UTC]
# _etl_loaded_at                 datetime64[ns]
# dtype: object

# %%
dim_schedules.to_sql('raw_schedules', con= postgres_engine, schema='staging', if_exists='append', method='multi', chunksize= 500, index= False)
# Out:
# 223

# %%
'''Seasons: Lists all seasons and the corresponding urls'''
limit= 200

url = "http://ergast.com/api/f1/seasons.json?limit={limit}".format(limit= limit)
    
response = requests.request("GET", url, headers=headers, data=payload)

season_str = response.json()['MRData']['SeasonTable']

season = pd.json_normalize(season_str, record_path =['Seasons'])
season['_etl_loaded_at']= datetime.now().strftime("%Y-%m-%d %H:%M:%S")
season
# Out:
#    season                                                url  \
# 0    1950  http://en.wikipedia.org/wiki/1950_Formula_One_...
# 1    1951  http://en.wikipedia.org/wiki/1951_Formula_One_...
# 2    1952  http://en.wikipedia.org/wiki/1952_Formula_One_...
# 3    1953  http://en.wikipedia.org/wiki/1953_Formula_One_...
# 4    1954  http://en.wikipedia.org/wiki/1954_Formula_One_...
# ..    ...                                                ...
# 69   2019  http://en.wikipedia.org/wiki/2019_Formula_One_...
# 70   2020  http://en.wikipedia.org/wiki/2020_Formula_One_...
# 71   2021  http://en.wikipedia.org/wiki/2021_Formula_One_...
# 72   2022  http://en.wikipedia.org/wiki/2022_Formula_One_...
# 73   2023  https://en.wikipedia.org/wiki/2023_Formula_One...
#
#          _etl_loaded_at
# 0   2023-07-15 08:15:30
# 1   2023-07-15 08:15:30
# 2   2023-07-15 08:15:30
# 3   2023-07-15 08:15:30
# 4   2023-07-15 08:15:30
# ..                  ...
# 69  2023-07-15 08:15:30
# 70  2023-07-15 08:15:30
# ...

# %%
# season= season.convert_dtypes()       #convert all columns to string, first

season[['_etl_loaded_at']]= season[['_etl_loaded_at']].apply(pd.to_datetime, format='%Y-%m-%d %H:%M:%S')
season.dtypes
# Out:
# season                    object
# url                       object
# _etl_loaded_at    datetime64[ns]
# dtype: object

# %%
season.to_sql('raw_seasons', con= postgres_engine, schema='staging', if_exists='append', method='multi', chunksize= 500, index= False,
                         )
# Out:
# 74

# %%
# '''Drivers: Lists all drivers'''
# limit= 1000

# url = "http://ergast.com/api/f1/drivers.json?limit={limit}".format(limit= limit)
    
# response = requests.request("GET", url, headers=headers, data=payload)

# drivers_str = response.json()['MRData']['DriverTable']

# drivers = pd.json_normalize(drivers_str, record_path =['Drivers'])
# drivers['_etl_loaded_at']= datetime.now().strftime("%Y-%m-%d %H:%M:%S")
# drivers

# %%
'''Drivers: Lists all drivers'''


url = "http://ergast.com/api/f1/drivers.json"
params= {
        'limit': 1000,
        'format': json,
        'offset': 0,
        }
    
response = requests.get(url, params= params)

drivers_data = response.json()['MRData']['DriverTable']

drivers = pd.json_normalize(drivers_data, record_path =['Drivers'])
drivers['_etl_loaded_at']= datetime.now().strftime("%Y-%m-%d %H:%M:%S")
drivers
# Out:
#       driverId                                             url givenName  \
# 0        abate  http://en.wikipedia.org/wiki/Carlo_Mario_Abate     Carlo
# 1    abecassis   http://en.wikipedia.org/wiki/George_Abecassis    George
# 2      acheson      http://en.wikipedia.org/wiki/Kenny_Acheson     Kenny
# 3        adams     http://en.wikipedia.org/wiki/Philippe_Adams  Philippe
# 4         ader          http://en.wikipedia.org/wiki/Walt_Ader      Walt
# ..         ...                                             ...       ...
# 852     zapico      http://en.wikipedia.org/wiki/Emilio_Zapico    Emilio
# 853       zhou        http://en.wikipedia.org/wiki/Guanyu_Zhou    Guanyu
# 854      zonta      http://en.wikipedia.org/wiki/Ricardo_Zonta   Ricardo
# 855      zorzi        http://en.wikipedia.org/wiki/Renzo_Zorzi     Renzo
# 856     zunino     http://en.wikipedia.org/wiki/Ricardo_Zunino   Ricardo
#
#     familyName dateOfBirth nationality permanentNumber code  \
# ...

# %%
# drivers= drivers.convert_dtypes()       #convert all columns to string, first

drivers[['_etl_loaded_at']]= drivers[['_etl_loaded_at']].apply(pd.to_datetime, format='%Y-%m-%d %H:%M:%S')
drivers[['dateOfBirth']]= drivers[['dateOfBirth']].apply(pd.to_datetime, format='%Y-%m-%d')
drivers.dtypes
# Out:
# driverId                   object
# url                        object
# givenName                  object
# familyName                 object
# dateOfBirth        datetime64[ns]
# nationality                object
# permanentNumber            object
# code                       object
# _etl_loaded_at     datetime64[ns]
# dtype: object

# %%
drivers.to_sql('raw_drivers', con= postgres_engine, schema='staging', if_exists='append', method='multi', chunksize= 500, index= False,
                         )
# Out:
# 857

# %%
# limit= 1000


# circuits_url = "http://ergast.com/api/f1/2022/2/circuits.json?limit={limit}".format(limit= limit)
    
# circuits_response = requests.request("GET", circuits_url, headers=headers, data=payload)

# circuits_str = circuits_response.json()['MRData']['CircuitTable']

# circuits = pd.json_normalize(circuits_str, record_path =['Circuits'],
#                              meta=['season', 'round']
#                              )

# circuits['_etl_loaded_at']= datetime.now().strftime("%Y-%m-%d %H:%M:%S")
# circuits

# %%
# '''Circuits: Lists all Circuits'''
# limit= 1500
# offset= 0
# payload = {}
# headers = {}
# years= [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023]
# # yr_round= 2
# circuits= pd.DataFrame(columns=['circuitId', 'url', 'circuitName', 'Location.lat', 'Location.long',
#        'Location.locality', 'Location.country', 'season', 'round'])
# for year in years:
#     print(year)
#     for yr_round in range(1,25):
#         try:
#             print (yr_round)
#             circuit_url = "http://ergast.com/api/f1/{year}/{yr_round}/circuits.json?limit={limit}&offset={offset}".format(year=year,yr_round=yr_round,limit= limit,offset= offset)
    
#             circuit_response = requests.request("GET", circuit_url, headers=headers, data=payload)

#             circuit_str = circuit_response.json()['MRData']['CircuitTable']

#             circuit = pd.json_normalize(circuit_str, record_path =['Circuits'],
#                              meta=['season', 'round']
#                              )
#             circuits= pd.concat([circuits, circuit], ignore_index=True)
#         except IndexError:
#             print("There was no round {} in {} season".format(yr_round, year))
#             pass

# %%
# circuits['_etl_loaded_at']= datetime.now().strftime("%Y-%m-%d %H:%M:%S")
# circuits=circuits.astype({'round': int, 'Location.long': float, 'Location.lat': float})
# circuits

# %%
'''Circuits: Lists all Circuits'''
limit= 1000
offset= 0
payload = {}
headers = {}

circuits= pd.DataFrame(columns=['circuitId', 'url', 'circuitName', 'Location.lat', 'Location.long',
       'Location.locality', 'Location.country', 'season'])
for year in years:
    print(year)

    circuit_url = "http://ergast.com/api/f1/{year}/circuits.json?limit={limit}&offset={offset}".format(year=year,limit= limit,offset= offset)

    circuit_response = requests.request("GET", circuit_url, headers=headers, data=payload)

    circuit_str = circuit_response.json()['MRData']['CircuitTable']

    circuit = pd.json_normalize(circuit_str, record_path =['Circuits'],
                        meta=['season']
                        )
    circuits= pd.concat([circuits, circuit], ignore_index=True)
    
    circuits['_etl_loaded_at']= datetime.now().strftime("%Y-%m-%d %H:%M:%S")
 
circuits
# Out:
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020
# 2021
# 2022
# 2023
#        circuitId                                                url  \
# 0    albert_park  http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 1       americas  http://en.wikipedia.org/wiki/Circuit_of_the_Am...
# 2        bahrain  http://en.wikipedia.org/wiki/Bahrain_Internati...
# 3          buddh  http://en.wikipedia.org/wiki/Buddh_Internation...
# 4      catalunya  http://en.wikipedia.org/wiki/Circuit_de_Barcel...
# ..           ...                                                ...
# 214       suzuka        http://en.wikipedia.org/wiki/Suzuka_Circuit
# 215        vegas  https://en.wikipedia.org/wiki/Las_Vegas_Grand_...
# 216   villeneuve  http://en.wikipedia.org/wiki/Circuit_Gilles_Vi...
# 217   yas_marina    http://en.wikipedia.org/wiki/Yas_Marina_Circuit
# 218    zandvoort     http://en.wikipedia.org/wiki/Circuit_Zandvoort
#
#                         circuitName Location.lat Location.long  \
# ...

# %%
circuits['circuitId'].unique
# Out:
# <bound method Series.unique of 0      albert_park
# 1         americas
# 2          bahrain
# 3            buddh
# 4        catalunya
#           ...
# 214         suzuka
# 215          vegas
# 216     villeneuve
# 217     yas_marina
# 218      zandvoort
# Name: circuitId, Length: 219, dtype: object>

# %%
#update datatypes
dim_circuits= circuits.astype({'Location.long': float, 'Location.lat': float})
dim_circuits[['_etl_loaded_at']]= dim_circuits[['_etl_loaded_at']].apply(pd.to_datetime, format='%Y-%m-%d %H:%M:%S')

#create the cordinate point using longitude and latitude
# dim_circuits['circuitLocationPoint'] = [Point(xy) for xy in zip(dim_circuits['Location.long'], dim_circuits['Location.lat'])] 

#rename column(s)
dim_circuits.rename(columns={'Location.lat': 'locationLat','Location.long': 'locationLong',
                              'Location.locality': 'locationLocality', 'Location.country': 'locationCountry'
                                  }, inplace=True)

dim_circuits= dim_circuits[['circuitId', 'url', 'circuitName', 'locationLat', 'locationLong',
                              'locationLocality', 'locationCountry', 'season', '_etl_loaded_at',
                              ]]
dim_circuits
# Out:
#        circuitId                                                url  \
# 0    albert_park  http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 1       americas  http://en.wikipedia.org/wiki/Circuit_of_the_Am...
# 2        bahrain  http://en.wikipedia.org/wiki/Bahrain_Internati...
# 3          buddh  http://en.wikipedia.org/wiki/Buddh_Internation...
# 4      catalunya  http://en.wikipedia.org/wiki/Circuit_de_Barcel...
# ..           ...                                                ...
# 214       suzuka        http://en.wikipedia.org/wiki/Suzuka_Circuit
# 215        vegas  https://en.wikipedia.org/wiki/Las_Vegas_Grand_...
# 216   villeneuve  http://en.wikipedia.org/wiki/Circuit_Gilles_Vi...
# 217   yas_marina    http://en.wikipedia.org/wiki/Yas_Marina_Circuit
# 218    zandvoort     http://en.wikipedia.org/wiki/Circuit_Zandvoort
#
#                         circuitName  locationLat  locationLong  \
# 0    Albert Park Grand Prix Circuit     -37.8497     144.96800
# ...

# %%
dim_circuits.to_sql('raw_circuits', con= postgres_engine, schema='staging', if_exists='append', method='multi', chunksize= 500, index= False,
                         )
# Out:
# 219

# %%
response = requests.request("GET", url, headers=headers, data=payload)
data_dict = xmltodict.parse(response.text)
data_dict_records= data_dict['MRData']['ConstructorTable']
unnested_metric_data = pd.json_normalize(data_dict_records, record_path =['Constructor'])
new_unnested_metric_data = unnested_metric_data
total= int(data_dict['MRData']['@total'])
limit= 1000
offset= 0

try:
    while total > offset:
        print(len(new_unnested_metric_data), limit, offset)
        url = "http://ergast.com/api/f1/constructors?limit={}&offset={}".format(limit,offset)
        response = requests.request("GET", url, headers=headers, data=payload)
        data_dict = xmltodict.parse(response.text)
        data_dict_records= data_dict['MRData']['ConstructorTable']
        new_nested_metric_data = pd.json_normalize(data_dict_records, record_path =['Constructor'])
        print(len(new_unnested_metric_data))
        unnested_metric_data= pd.concat([unnested_metric_data, new_unnested_metric_data], ignore_index=True)
        offset= limit + offset
        # print(len(offset))
except:
    print('all pages merged')

unnested_metric_data
